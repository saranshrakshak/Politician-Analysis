# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rep.columns

# %%
rep["Office Type"].value_counts()

# %%
rep["Candidate"] = rep["Candidate"].str.lower()
rep = rep.sort_values("Candidate")
rep["Candidate"]

# %%
# Trump and Susan B. Anthony Endorsed
rep[(rep['Trump Endorsed?']=='Yes') & (rep['Susan B. Anthony Endorsed?']=='Yes')]

# %%
prim_winner = rep[rep['Primary Status']=='Advanced']

# %%
# Primary Winners by Large Majority
prim_winner[prim_winner['Primary %']>=75.0]
